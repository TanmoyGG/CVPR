# %% [markdown]
# <a href="https://colab.research.google.com/github/TanmoyGG/CVPR/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import os
from PIL import Image
from pathlib import Path
import pillow_heif
import numpy as np

try:
    import rawpy
    HAS_RAWPY = True
    print("✓ rawpy successfully imported")
except ImportError as e:
    HAS_RAWPY = False
    print(f"✗ rawpy import failed: {e}")
    print("Installing rawpy...")
    import subprocess
    subprocess.check_call([__import__('sys').executable, "-m", "pip", "install", "rawpy"])
    import rawpy
    HAS_RAWPY = True
    print("✓ rawpy installed successfully")

try:
    import imageio
    HAS_IMAGEIO = True
    print("✓ imageio successfully imported")
except ImportError as e:
    HAS_IMAGEIO = False
    print(f"✗ imageio import failed: {e}")
    print("Installing imageio...")
    import subprocess
    subprocess.check_call([__import__('sys').executable, "-m", "pip", "install", "imageio", "imageio-ffmpeg"])
    import imageio
    HAS_IMAGEIO = True
    print("✓ imageio installed successfully")

try:
    import cv2
    HAS_CV2 = True
    print("✓ opencv (cv2) successfully imported")
except ImportError as e:
    HAS_CV2 = False
    print(f"✗ opencv import failed: {e}")
    print("Installing opencv...")
    import subprocess
    subprocess.check_call([__import__('sys').executable, "-m", "pip", "install", "opencv-python"])
    import cv2
    HAS_CV2 = True
    print("✓ opencv installed successfully")

# Register HEIF opener with PIL
pillow_heif.register_heif_opener()
# Out:
# ✓ rawpy successfully imported
# ✓ imageio successfully imported
# ✓ opencv (cv2) successfully imported

# %%
# Test DNG processing (optional - for debugging)
test_dng_folder = 'dataset/22-46887-1'
if os.path.exists(test_dng_folder):
    dng_files = [f for f in os.listdir(test_dng_folder) if f.lower().endswith('.dng')]
    if dng_files:
        print(f"\nFound {len(dng_files)} DNG files: {dng_files}")
        print("Testing DNG conversion on first file...")
        test_path = os.path.join(test_dng_folder, dng_files[0])

        # Try rawpy first
        if HAS_RAWPY:
            try:
                with rawpy.imread(test_path) as raw:
                    rgb_array = raw.postprocess()
                    print(f"✓ rawpy conversion successful: {rgb_array.shape}")
            except Exception as e:
                print(f"✗ rawpy failed: {e}")

                # Try imageio
                if HAS_IMAGEIO:
                    print("Trying imageio...")
                    try:
                        img_array = imageio.imread(test_path)
                        print(f"✓ imageio conversion successful: {img_array.shape}")
                    except Exception as e2:
                        print(f"✗ imageio also failed: {e2}")

                        # Try OpenCV
                        if HAS_CV2:
                            print("Trying opencv (cv2)...")
                            try:
                                img_cv = cv2.imread(test_path, cv2.IMREAD_UNCHANGED)
                                if img_cv is not None:
                                    print(f"✓ OpenCV conversion successful: {img_cv.shape}")
                                else:
                                    print("✗ OpenCV returned None for DNG")
                            except Exception as e3:
                                print(f"✗ OpenCV also failed: {e3}")
        else:
            print("rawpy not available, trying imageio...")
            if HAS_IMAGEIO:
                try:
                    img_array = imageio.imread(test_path)
                    print(f"✓ imageio conversion successful: {img_array.shape}")
                except Exception as e:
                    print(f"✗ imageio failed: {e}")
                    if HAS_CV2:
                        print("Trying opencv (cv2)...")
                        try:
                            img_cv = cv2.imread(test_path, cv2.IMREAD_UNCHANGED)
                            if img_cv is not None:
                                print(f"✓ OpenCV conversion successful: {img_cv.shape}")
                            else:
                                print("✗ OpenCV returned None for DNG")
                        except Exception as e3:
                            print(f"✗ OpenCV also failed: {e3}")
# Out:
# Found 3 DNG files: ['IMG_1244(1).DNG', 'IMG_1244.DNG', 'IMG_1247.DNG']
# Testing DNG conversion on first file...
# ✗ rawpy failed: b'Unsupported file format or not RAW file'
# Trying imageio...
# ✓ imageio conversion successful: (3088, 2316, 3)
# C:\Users\tanmo\AppData\Local\Temp\ipykernel_23852\3222239668.py:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_array = imageio.imread(test_path)

# %%
# Define paths
source_folder = 'dataset'
output_folder = 'dataset_processed'
target_size = (524, 524)

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

print(f"Source folder: {source_folder}")
print(f"Output folder: {output_folder}")
print(f"Target size: {target_size}")
# Out:
# Source folder: dataset
# Output folder: dataset_processed
# Target size: (524, 524)

# %%
# Get all unique ID folders
unique_id_folders = [f for f in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, f))]
print(f"Found {len(unique_id_folders)} unique ID folders")
print(f"First 5 folders: {unique_id_folders[:5]}")
# Out:
# Found 66 unique ID folders
# First 5 folders: ['21-45902-3', '22-46138-1', '22-46139-1', '22-46141-1', '22-46275-1']

# %%
# Function to process a single image
def process_image(input_path, output_path, target_size=(524, 524)):
    """
    Process an image: crop to square and resize to target size without flipping
    Supports: JPG, JPEG, PNG, HEIC, DNG

    Args:
        input_path: Path to input image
        output_path: Path to save processed image
        target_size: Tuple of (width, height) for resizing
    """
    try:
        # Check if file is DNG
        file_ext = os.path.splitext(input_path)[1].lower()

        if file_ext == '.dng':
            # Handle DNG files with multiple fallback methods
            img = None

            # Try rawpy first
            if HAS_RAWPY:
                try:
                    with rawpy.imread(input_path) as raw:
                        rgb_array = raw.postprocess()
                        img = Image.fromarray(rgb_array)
                except:
                    pass

            # Fallback to imageio
            if img is None and HAS_IMAGEIO:
                try:
                    img_array = imageio.imread(input_path)
                    if len(img_array.shape) == 3 and img_array.shape[2] >= 3:
                        img = Image.fromarray(img_array[:, :, :3].astype('uint8'))
                    else:
                        img = Image.fromarray(img_array.astype('uint8'))
                except:
                    pass

            # Fallback to OpenCV
            if img is None and HAS_CV2:
                try:
                    img_cv = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
                    if img_cv is not None:
                        # OpenCV reads in BGR, convert to RGB
                        if len(img_cv.shape) == 3 and img_cv.shape[2] >= 3:
                            img_rgb = cv2.cvtColor(img_cv[:, :, :3], cv2.COLOR_BGR2RGB)
                            img = Image.fromarray(img_rgb.astype('uint8'))
                        else:
                            img = Image.fromarray(img_cv.astype('uint8'))
                except:
                    pass

            if img is None:
                print(f"No suitable library available to process DNG: {input_path}")
                return False
        else:
            # Open other image formats
            img = Image.open(input_path)

        # Handle EXIF orientation to prevent flipping (skip for DNG as it's already processed)
        if file_ext != '.dng':
            try:
                from PIL.ExifTags import TAGS
                exif_data = img._getexif()
                if exif_data:
                    for tag_id, value in exif_data.items():
                        tag = TAGS.get(tag_id, tag_id)
                        if tag == 'Orientation':
                            # Orientation tag values:
                            # 1 = normal, 2 = flipped horizontally, 3 = rotated 180,
                            # 4 = flipped vertically, 5 = transposed, 6 = rotated 90 CW,
                            # 7 = transposed, 8 = rotated 90 CCW
                            if value == 2:
                                img = img.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
                            elif value == 3:
                                img = img.rotate(180, expand=False)
                            elif value == 4:
                                img = img.transpose(Image.Transpose.FLIP_TOP_BOTTOM)
                            elif value == 5:
                                img = img.transpose(Image.Transpose.TRANSPOSE)
                            elif value == 6:
                                img = img.rotate(270, expand=False)
                            elif value == 7:
                                img = img.transpose(Image.Transpose.TRANSVERSE)
                            elif value == 8:
                                img = img.rotate(90, expand=False)
            except:
                # If EXIF data is not available, continue without modification
                pass

        # Convert to RGB if necessary (for PNG with transparency or HEIC)
        if img.mode in ('RGBA', 'LA', 'P'):
            # Create a white background
            background = Image.new('RGB', img.size, (255, 255, 255))
            if img.mode == 'P':
                img = img.convert('RGBA')
            background.paste(img, mask=img.split()[-1] if img.mode in ('RGBA', 'LA') else None)
            img = background
        elif img.mode != 'RGB':
            img = img.convert('RGB')

        # Crop to square from center
        width, height = img.size
        min_dimension = min(width, height)

        # Calculate crop coordinates to center the crop
        left = (width - min_dimension) // 2
        top = (height - min_dimension) // 2
        right = left + min_dimension
        bottom = top + min_dimension

        # Crop to square
        img_cropped = img.crop((left, top, right, bottom))

        # Resize image to target size
        img_resized = img_cropped.resize(target_size, Image.Resampling.LANCZOS)

        # Save as JPG without EXIF data to prevent any orientation issues
        img_resized.save(output_path, 'JPEG', quality=95, exif=b'')

        return True
    except Exception as e:
        print(f"Error processing {input_path}: {str(e)}")
        return False

# %%
# Process all images
total_images = 0
processed_images = 0
failed_images = 0

# Supported image extensions
image_extensions = {'.jpg', '.jpeg', '.png', '.heic', '.dng', '.JPG', '.JPEG', '.PNG', '.HEIC', '.DNG'}

for folder_name in unique_id_folders:
    # Create corresponding output folder
    input_folder_path = os.path.join(source_folder, folder_name)
    output_folder_path = os.path.join(output_folder, folder_name)
    os.makedirs(output_folder_path, exist_ok=True)

    # Get all image files in the folder
    image_files = [f for f in os.listdir(input_folder_path)
                   if os.path.splitext(f)[1] in image_extensions]

    print(f"\nProcessing folder: {folder_name} ({len(image_files)} images)")

    # Sort image files for consistent ordering
    image_files.sort()

    # Process each image with sequential numbering
    for idx, image_file in enumerate(image_files, start=1):
        total_images += 1

        # Input and output paths
        input_path = os.path.join(input_folder_path, image_file)

        # Rename as sequential: 1.jpg, 2.jpg, 3.jpg, etc.
        output_filename = f'{idx}.jpg'
        output_path = os.path.join(output_folder_path, output_filename)

        # Process the image
        if process_image(input_path, output_path, target_size):
            processed_images += 1
            print(f"  ✓ Processed: {image_file} -> {output_filename}")
        else:
            failed_images += 1

print("\n" + "="*60)
print("Processing Complete!")
print(f"Total images: {total_images}")
print(f"Successfully processed: {processed_images}")
print(f"Failed: {failed_images}")
print("="*60)
# Out:
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (2).jpeg -> 12.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (20).jpeg -> 13.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (3).jpeg -> 14.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (4).jpeg -> 15.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (5).jpeg -> 16.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (6).jpeg -> 17.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (7).jpeg -> 18.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (8).jpeg -> 19.jpg
#   ✓ Processed: WhatsApp Image 2025-12-29 at 9.14.39 PM (9).jpeg -> 20.jpg
#
# Processing folder: 22-46887-1 (20 images)
#   ✓ Processed: IMG_1240(1).JPG -> 1.jpg
#   ✓ Processed: IMG_1240(2).JPG -> 2.jpg
#   ✓ Processed: IMG_1240.JPG -> 3.jpg
#   ✓ Processed: IMG_1241(1).JPG -> 4.jpg
#   ✓ Processed: IMG_1241.JPG -> 5.jpg
# C:\Users\tanmo\AppData\Local\Temp\ipykernel_23852\3678116088.py:32: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_array = imageio.imread(input_path)
#   ✓ Processed: IMG_1244(1).DNG -> 6.jpg
#   ✓ Processed: IMG_1244.DNG -> 7.jpg
#   ✓ Processed: IMG_1247.DNG -> 8.jpg
#   ✓ Processed: IMG_1251(1).JPG -> 9.jpg
#   ✓ Processed: IMG_1251.JPG -> 10.jpg
#   ✓ Processed: IMG_1252.JPG -> 11.jpg
#   ✓ Processed: IMG_1254.JPG -> 12.jpg
#   ✓ Processed: IMG_1256.JPG -> 13.jpg
#   ✓ Processed: IMG_1258.JPG -> 14.jpg
#   ✓ Processed: IMG_1259(1).JPG -> 15.jpg
#   ✓ Processed: IMG_1259.JPG -> 16.jpg
#   ✓ Processed: IMG_1260.JPG -> 17.jpg
#   ✓ Processed: IMG_1261.JPG -> 18.jpg
#   ✓ Processed: IMG_1262.JPG -> 19.jpg
#   ✓ Processed: IMG_1272.JPG -> 20.jpg
#
# Processing folder: 22-46945-1 (20 images)
#   ✓ Processed: 1.png -> 1.jpg
#   ✓ Processed: 10.png -> 2.jpg
#   ✓ Processed: 11.png -> 3.jpg
#   ✓ Processed: 12.png -> 4.jpg
#   ✓ Processed: 13.png -> 5.jpg
#   ✓ Processed: 14.png -> 6.jpg
#   ✓ Processed: 15.png -> 7.jpg
#   ✓ Processed: 16.png -> 8.jpg
#   ✓ Processed: 17.png -> 9.jpg
#   ✓ Processed: 18.png -> 10.jpg
#   ✓ Processed: 19.png -> 11.jpg
#   ✓ Processed: 2.png -> 12.jpg
#   ✓ Processed: 20.png -> 13.jpg
#   ✓ Processed: 3.png -> 14.jpg
#   ✓ Processed: 4.png -> 15.jpg
#
# Processing folder: 22-48064-2 (20 images)
#   ✓ Processed: IMG_1055.JPG -> 1.jpg
#   ✓ Processed: IMG_1056.JPG -> 2.jpg
#   ✓ Processed: IMG_1057.JPG -> 3.jpg
#   ✓ Processed: IMG_1058.JPG -> 4.jpg
#   ✓ Processed: IMG_1059.JPG -> 5.jpg
#   ✓ Processed: IMG_1060.JPG -> 6.jpg
#   ✓ Processed: IMG_1061.JPG -> 7.jpg
#   ✓ Processed: IMG_1062.JPG -> 8.jpg
#   ✓ Processed: IMG_1066.JPG -> 9.jpg
#   ✓ Processed: IMG_1067.JPG -> 10.jpg
#   ✓ Processed: IMG_1068.JPG -> 11.jpg
#   ✓ Processed: IMG_1069.JPG -> 12.jpg
#   ✓ Processed: IMG_1070.JPG -> 13.jpg
#   ✓ Processed: IMG_1071.JPG -> 14.jpg
#   ✓ Processed: IMG_1072.JPG -> 15.jpg
#   ✓ Processed: IMG_1073.JPG -> 16.jpg
#   ✓ Processed: IMG_1074.JPG -> 17.jpg
#   ✓ Processed: IMG_1075.JPG -> 18.jpg
#   ✓ Processed: IMG_1076.JPG -> 19.jpg
#   ✓ Processed: IMG_1077.JPG -> 20.jpg
#
# Processing folder: 22-48091-2 (20 images)
#   ✓ Processed: Photo_01.heic -> 1.jpg
#   ✓ Processed: Photo_02.heic -> 2.jpg
#   ✓ Processed: Photo_03.heic -> 3.jpg
#   ✓ Processed: Photo_04.heic -> 4.jpg
#   ✓ Processed: Photo_05.heic -> 5.jpg
#   ✓ Processed: Photo_06.jpg -> 6.jpg
#   ✓ Processed: Photo_07.jpg -> 7.jpg
#   ✓ Processed: Photo_08.jpg -> 8.jpg
#   ✓ Processed: Photo_09.heic -> 9.jpg
#   ✓ Processed: Photo_10.heic -> 10.jpg
#   ✓ Processed: Photo_11.heic -> 11.jpg
#   ✓ Processed: Photo_12.heic -> 12.jpg
#   ✓ Processed: Photo_13.heic -> 13.jpg
#   ✓ Processed: Photo_14.heic -> 14.jpg
#   ✓ Processed: Photo_15.heic -> 15.jpg
#   ✓ Processed: Photo_16.heic -> 16.jpg
#   ✓ Processed: Photo_17.heic -> 17.jpg
#   ✓ Processed: Photo_18.jpg -> 18.jpg
#   ✓ Processed: Photo_19.heic -> 19.jpg
#   ✓ Processed: Photo_21.heic -> 20.jpg
#
# Processing folder: 22-48133-2 (20 images)
#   ✓ Processed: 22-48133-2(1).jpg -> 1.jpg
#   ✓ Processed: 22-48133-2(10).jpg -> 2.jpg
#   ✓ Processed: 22-48133-2(11).jpg -> 3.jpg
#   ✓ Processed: 22-48133-2(12).jpg -> 4.jpg
#   ✓ Processed: 22-48133-2(13).jpg -> 5.jpg
#   ✓ Processed: 22-48133-2(14).jpg -> 6.jpg
#   ✓ Processed: 22-48133-2(15).jpg -> 7.jpg
#   ✓ Processed: 22-48133-2(16).jpg -> 8.jpg
#   ✓ Processed: 22-48133-2(17).jpg -> 9.jpg
#   ✓ Processed: 22-48133-2(18).jpg -> 10.jpg
#   ✓ Processed: PXL_20251220_152034947.jpg -> 16.jpg
#   ✓ Processed: PXL_20251220_152039220.jpg -> 17.jpg
#   ✓ Processed: PXL_20251220_152043407.jpg -> 18.jpg
#   ✓ Processed: PXL_20251220_152044966.jpg -> 19.jpg
#   ✓ Processed: PXL_20251220_152047116.jpg -> 20.jpg
#
# Processing folder: 22-49451-3 (20 images)
#   ✓ Processed: pic1.JPG -> 1.jpg
#   ✓ Processed: pic10.jpg -> 2.jpg
#   ✓ Processed: pic11.jpg -> 3.jpg
#   ✓ Processed: pic12.jpg -> 4.jpg
#   ✓ Processed: pic13.jpg -> 5.jpg
#   ✓ Processed: pic14.jpg -> 6.jpg
#   ✓ Processed: pic15.jpg -> 7.jpg
#   ✓ Processed: pic16.jpg -> 8.jpg
#   ✓ Processed: pic17.jpg -> 9.jpg
#   ✓ Processed: pic18.jpg -> 10.jpg
#   ✓ Processed: pic19.jpg -> 11.jpg
#   ✓ Processed: pic2.jpg -> 12.jpg
#   ✓ Processed: pic20.jpg -> 13.jpg
#   ✓ Processed: pic3.jpg -> 14.jpg
#   ✓ Processed: pic4.jpg -> 15.jpg
#   ✓ Processed: pic5.jpg -> 16.jpg
#   ✓ Processed: pic6.jpg -> 17.jpg
#   ✓ Processed: pic7.jpg -> 18.jpg
#   ✓ Processed: pic8.jpg -> 19.jpg
#   ✓ Processed: pic9.jpg -> 20.jpg
#
# Processing folder: 22-49453-3 (20 images)
#   ✓ Processed: 20251229_101314.jpg -> 1.jpg
#   ✓ Processed: 20251229_101319.jpg -> 2.jpg
#   ✓ Processed: 20251229_101322.jpg -> 3.jpg
#   ✓ Processed: 20251229_101329.jpg -> 4.jpg
#   ✓ Processed: 20251229_101337.jpg -> 5.jpg
#   ✓ Processed: 20251229_101342.jpg -> 6.jpg
#   ✓ Processed: 20251229_101352.jpg -> 7.jpg
#   ✓ Processed: 20251229_101403.jpg -> 8.jpg
#   ✓ Processed: 20251229_101408.jpg -> 9.jpg
#   ✓ Processed: 20251229_101412.jpg -> 10.jpg
#   ✓ Processed: WIN_20251229_10_15_40_Pro.jpg -> 11.jpg
#   ✓ Processed: WIN_20251229_10_15_41_Pro.jpg -> 12.jpg
#   ✓ Processed: WIN_20251229_10_15_44_Pro.jpg -> 13.jpg
#   ✓ Processed: WIN_20251229_10_15_54_Pro.jpg -> 14.jpg
#   ✓ Processed: WIN_20251229_10_16_01_Pro.jpg -> 15.jpg
#   ✓ Processed: WIN_20251229_10_16_10_Pro.jpg -> 16.jpg
#   ✓ Processed: WIN_20251229_10_16_13_Pro.jpg -> 17.jpg
#   ✓ Processed: WIN_20251229_10_16_15_Pro.jpg -> 18.jpg
#   ✓ Processed: WIN_20251229_10_16_19_Pro.jpg -> 19.jpg
#   ✓ Processed: WIN_20251229_10_16_25_Pro.jpg -> 20.jpg
#
# Processing folder: 22-49507-3 (20 images)
#   ✓ Processed: IMG_3638.JPG -> 1.jpg
#   ✓ Processed: IMG_3639.JPG -> 2.jpg
#   ✓ Processed: WhatsApp Image 2025-12-20 at 10.24.31_a63d31e8 - Copy (77).jpg -> 12.jpg
#   ✓ Processed: WhatsApp Image 2025-12-20 at 10.24.32_a867d10e - Copy (10).jpg -> 13.jpg
#   ✓ Processed: WhatsApp Image 2025-12-20 at 10.24.32_a867d10e - Copy (11).jpg -> 14.jpg
#   ✓ Processed: WhatsApp Image 2025-12-20 at 10.24.32_a867d10e - Copy (12).jpg -> 15.jpg
#   ✓ Processed: WhatsApp Image 2025-12-20 at 10.24.32_a867d10e - Copy (13).jpg -> 16.jpg
#   ✓ Processed: frame00001 - Copy (30).png -> 17.jpg
#   ✓ Processed: frame00001 - Copy (32).png -> 18.jpg
#   ✓ Processed: frame00001 - Copy (47).png -> 19.jpg
#   ✓ Processed: frame00001 - Copy (54).png -> 20.jpg
#
# Processing folder: 22-49745-3 (20 images)
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.05 PM (1).jpeg -> 1.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.05 PM.jpeg -> 2.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.06 PM (1).jpeg -> 3.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.06 PM.jpeg -> 4.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.07 PM (1).jpeg -> 5.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.07 PM.jpeg -> 6.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.08 PM.jpeg -> 7.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.09 PM.jpeg -> 8.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.10 PM (1).jpeg -> 9.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.10 PM.jpeg -> 10.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.12 PM (1).jpeg -> 11.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.12 PM.jpeg -> 12.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.13 PM (1).jpeg -> 13.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.13 PM.jpeg -> 14.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.14 PM (1).jpeg -> 15.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.14 PM.jpeg -> 16.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.15 PM.jpeg -> 17.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.16 PM.jpeg -> 18.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.17 PM (1).jpeg -> 19.jpg
#   ✓ Processed: WhatsApp Image 2025-12-27 at 11.36.17 PM.jpeg -> 20.jpg
#
# Processing folder: 22-49783-3 (20 images)
#   ✓ Processed: tonmoy1.jpg -> 1.jpg
#   ✓ Processed: tonmoy10.jpg -> 2.jpg
#   ✓ Processed: tonmoy11.jpg -> 3.jpg
#   ✓ Processed: tonmoy12.jpg -> 4.jpg
#   ✓ Processed: tonmoy13.jpg -> 5.jpg
#   ✓ Processed: tonmoy14.jpg -> 6.jpg
#   ✓ Processed: tonmoy15.jpg -> 7.jpg
#   ✓ Processed: tonmoy16.jpg -> 8.jpg
#   ✓ Processed: tonmoy17.jpg -> 9.jpg
#   ✓ Processed: tonmoy18.jpg -> 10.jpg
#   ✓ Processed: tonmoy19.jpg -> 11.jpg
#   ✓ Processed: tonmoy2.jpg -> 12.jpg
#   ✓ Processed: tonmoy20.jpg -> 13.jpg
#   ✓ Processed: tonmoy3.jpg -> 14.jpg
#   ✓ Processed: tonmoy4.jpg -> 15.jpg
#   ✓ Processed: tonmoy5.jpg -> 16.jpg
#   ✓ Processed: tonmoy6.jpg -> 17.jpg
#   ✓ Processed: tonmoy7.jpg -> 18.jpg
#   ✓ Processed: tonmoy8.jpg -> 19.jpg
#   ✓ Processed: tonmoy9.jpg -> 20.jpg
#
# Processing folder: 22-49791-3 (20 images)
#   ✓ Processed: galib1.jpg -> 1.jpg
#   ✓ Processed: galib10.jpg -> 2.jpg
#   ✓ Processed: galib11.jpg -> 3.jpg
#   ✓ Processed: galib12.jpg -> 4.jpg
#   ✓ Processed: galib13.jpg -> 5.jpg
#   ✓ Processed: galib14.jpg -> 6.jpg
#   ✓ Processed: galib15.jpg -> 7.jpg
#   ✓ Processed: galib16.jpg -> 8.jpg
#   ✓ Processed: galib17.jpg -> 9.jpg
#   ✓ Processed: galib18.jpg -> 10.jpg
#   ✓ Processed: galib19.jpg -> 11.jpg
#   ✓ Processed: galib2.jpg -> 12.jpg
#   ✓ Processed: galib20.jpg -> 13.jpg
#   ✓ Processed: galib3.jpg -> 14.jpg
#   ✓ Processed: galib4.jpg -> 15.jpg
#   ✓ Processed: galib5.jpg -> 16.jpg
#   ✓ Processed: galib6.jpg -> 17.jpg
#   ✓ Processed: galib7.jpg -> 18.jpg
#   ✓ Processed: galib8.jpg -> 19.jpg
#   ✓ Processed: galib9.jpg -> 20.jpg
#
# Processing folder: 22-49800-3 (20 images)
#   ✓ Processed: sajid_image1.jpeg -> 1.jpg
#   ✓ Processed: sajid_image10.jpeg -> 2.jpg
#   ✓ Processed: sajid_image11.jpeg -> 3.jpg
#   ✓ Processed: sajid_image12.jpeg -> 4.jpg
#   ✓ Processed: sajid_image13.jpeg -> 5.jpg
#   ✓ Processed: sajid_image14.jpeg -> 6.jpg
#   ✓ Processed: sajid_image15.jpeg -> 7.jpg
#   ✓ Processed: sajid_image16.jpeg -> 8.jpg
#   ✓ Processed: sajid_image17.jpeg -> 9.jpg
#   ✓ Processed: sajid_image18.jpeg -> 10.jpg
#   ✓ Processed: sajid_image19.jpeg -> 11.jpg
#   ✓ Processed: sajid_image2.jpeg -> 12.jpg
#   ✓ Processed: sajid_image20.jpeg -> 13.jpg
#   ✓ Processed: sajid_image3.jpeg -> 14.jpg
#   ✓ Processed: sajid_image4.jpeg -> 15.jpg
#   ✓ Processed: sajid_image5.jpeg -> 16.jpg
#   ✓ Processed: sajid_image6.jpeg -> 17.jpg
#   ✓ Processed: sajid_image7.jpeg -> 18.jpg
#   ✓ Processed: sajid_image8.jpeg -> 19.jpg
#   ✓ Processed: sajid_image9.jpeg -> 20.jpg
#
# Processing folder: 22-49824-3 (20 images)
#   ✓ Processed: monami1.jpg -> 1.jpg
#   ✓ Processed: monami10.jpg -> 2.jpg
#   ✓ Processed: monami11.jpg -> 3.jpg
#   ✓ Processed: monami12.jpg -> 4.jpg
#   ✓ Processed: monami13.jpg -> 5.jpg
#   ✓ Processed: monami14.jpg -> 6.jpg
#   ✓ Processed: monami15.jpg -> 7.jpg
#   ✓ Processed: monami16.jpg -> 8.jpg
#   ✓ Processed: monami17.jpg -> 9.jpg
#   ✓ Processed: monami18.jpg -> 10.jpg
#   ✓ Processed: monami19.jpg -> 11.jpg
#   ✓ Processed: monami2.jpg -> 12.jpg
#   ✓ Processed: monami20.jpg -> 13.jpg
#   ✓ Processed: monami3.jpg -> 14.jpg
#   ✓ Processed: monami4.jpg -> 15.jpg
#   ✓ Processed: frame00203 - Copy (22).png -> 4.jpg
#   ✓ Processed: shared image (121) - Copy.jpg -> 5.jpg
#   ✓ Processed: shared image (122) - Copy.jpg -> 6.jpg
#   ✓ Processed: shared image (123) - Copy.jpg -> 7.jpg
#   ✓ Processed: shared image (124) - Copy.jpg -> 8.jpg
#   ✓ Processed: shared image (300) - Copy.jpg -> 9.jpg
#   ✓ Processed: shared image (301) - Copy.jpg -> 10.jpg
#   ✓ Processed: shared image (302) - Copy.jpg -> 11.jpg
#   ✓ Processed: shared image (303) - Copy.jpg -> 12.jpg
#   ✓ Processed: shared image (73) - Copy.jpg -> 13.jpg
#   ✓ Processed: shared image (74) - Copy.jpg -> 14.jpg
#   ✓ Processed: shared image (75) - Copy.jpg -> 15.jpg
#   ✓ Processed: shared image (76) - Copy.jpg -> 16.jpg
#   ✓ Processed: shared image - Copy (9).jpg -> 17.jpg
#   ✓ Processed: shared image - Copy (95) - Copy.jpg -> 18.jpg
#   ✓ Processed: shared image - Copy (95).jpg -> 19.jpg
#   ✓ Processed: shared image - Copy (96) - Copy.jpg -> 20.jpg
#
# Processing folder: 22-49862-3 (20 images)
#   ✓ Processed: IMG_20251224_214053.jpg -> 1.jpg
#   ✓ Processed: IMG_20251224_214058.jpg -> 2.jpg
#   ✓ Processed: IMG_20251224_214100.jpg -> 3.jpg
#   ✓ Processed: IMG_20251224_214104.jpg -> 4.jpg
#   ✓ Processed: IMG_20251224_214105.jpg -> 5.jpg
#   ✓ Processed: IMG_20251224_214107.jpg -> 6.jpg
#   ✓ Processed: IMG_20251224_214109.jpg -> 7.jpg
#   ✓ Processed: IMG_20251224_214110.jpg -> 8.jpg
#   ✓ Processed: IMG_20251224_214111.jpg -> 9.jpg
#   ✓ Processed: IMG_20251224_214114.jpg -> 10.jpg
#   ✓ Processed: IMG_20251224_214116.jpg -> 11.jpg
#   ✓ Processed: IMG_20251224_214118.jpg -> 12.jpg
#   ✓ Processed: IMG_20251224_214119.jpg -> 13.jpg
#   ✓ Processed: IMG_20251224_214121.jpg -> 14.jpg
#   ✓ Processed: IMG_20251224_214123.jpg -> 15.jpg
#   ✓ Processed: IMG_20251224_214124.jpg -> 16.jpg
#   ✓ Processed: IMG_20251224_214125.jpg -> 17.jpg
#   ✓ Processed: IMG_20251224_214144.jpg -> 18.jpg
#   ✓ Processed: IMG_20251224_214146.jpg -> 19.jpg
#   ✓ Processed: IMG_20251224_214147.jpg -> 20.jpg
#
# Processing folder: 23-50158-1 (20 images)
#   ✓ Processed: 20251220_165350.jpg -> 1.jpg
#   ✓ Processed: 20251220_165436.jpg -> 2.jpg
#   ✓ Processed: 20251220_165442.jpg -> 3.jpg
#   ✓ Processed: 20251220_165503.jpg -> 4.jpg
#   ✓ Processed: 20251220_165607.jpg -> 5.jpg
#   ✓ Processed: 20251220_165612.jpg -> 6.jpg
#   ✓ Processed: 20251220_165619.jpg -> 7.jpg
#   ✓ Processed: 20251220_165623.jpg -> 8.jpg
#   ✓ Processed: 20251220_165701.jpg -> 9.jpg
#   ✓ Processed: IMG_20251225_222351.jpg -> 15.jpg
#   ✓ Processed: IMG_20251225_222553.jpg -> 16.jpg
#   ✓ Processed: IMG_20251225_222605.jpg -> 17.jpg
#   ✓ Processed: IMG_20251225_222608.jpg -> 18.jpg
#   ✓ Processed: IMG_20251225_222610.jpg -> 19.jpg
#   ✓ Processed: IMG_20251225_222613.jpg -> 20.jpg
#
# Processing folder: 23-51127-1 (20 images)
#   ✓ Processed: 11.jpg -> 1.jpg
#   ✓ Processed: 13.jpg -> 2.jpg
#   ✓ Processed: 16.jpg -> 3.jpg
#   ✓ Processed: 20.jpg -> 4.jpg
#   ✓ Processed: 22.jpg -> 5.jpg
#   ✓ Processed: 24.jpg -> 6.jpg
#   ✓ Processed: 26.jpg -> 7.jpg
#   ✓ Processed: 27.jpg -> 8.jpg
#   ✓ Processed: 3.jpg -> 9.jpg
#   ✓ Processed: 31.jpg -> 10.jpg
#   ✓ Processed: 32.jpg -> 11.jpg
#   ✓ Processed: 39.jpg -> 12.jpg
#   ✓ Processed: 4.jpg -> 13.jpg
#   ✓ Processed: 44.jpg -> 14.jpg
#   ✓ Processed: 5.jpg -> 15.jpg
#   ✓ Processed: 53.jpg -> 16.jpg
#   ✓ Processed: 54.jpg -> 17.jpg
#   ✓ Processed: 62.jpg -> 18.jpg
#   ✓ Processed: 66.jpg -> 19.jpg
#   ✓ Processed: 9.jpg -> 20.jpg
#
# Processing folder: 23-53577-3 (20 images)
#   ✓ Processed: IMG_4634.HEIC -> 1.jpg
#   ✓ Processed: IMG_4635.HEIC -> 2.jpg
#   ✓ Processed: IMG_4636.HEIC -> 3.jpg
#   ✓ Processed: IMG_4637.HEIC -> 4.jpg
#   ✓ Processed: IMG_4638.HEIC -> 5.jpg
#   ✓ Processed: IMG_4639.HEIC -> 6.jpg
#   ✓ Processed: IMG_4640.HEIC -> 7.jpg
#   ✓ Processed: IMG_4641.HEIC -> 8.jpg
#   ✓ Processed: IMG_4642.HEIC -> 9.jpg
#   ✓ Processed: IMG_4643.HEIC -> 10.jpg
#   ✓ Processed: IMG_4644.HEIC -> 11.jpg
#   ✓ Processed: IMG_4645.HEIC -> 12.jpg
#   ✓ Processed: IMG_4646.HEIC -> 13.jpg
#   ✓ Processed: IMG_4647.HEIC -> 14.jpg
#   ✓ Processed: IMG_4648.HEIC -> 15.jpg
#   ✓ Processed: IMG_4649.HEIC -> 16.jpg
#   ✓ Processed: IMG_4650.HEIC -> 17.jpg
#   ✓ Processed: IMG_4651.HEIC -> 18.jpg
#   ✓ Processed: IMG_4652.HEIC -> 19.jpg
#   ✓ Processed: IMG_4653.HEIC -> 20.jpg
#
# ============================================================
# Processing Complete!
# Total images: 1319
# Successfully processed: 1319
# Failed: 0
# ============================================================

# %%
# Verification: Check the processed dataset
print("\nVerification of processed dataset:")
print("="*60)

processed_folders = [f for f in os.listdir(output_folder) if os.path.isdir(os.path.join(output_folder, f))]
print(f"Total folders in dataset_processed: {len(processed_folders)}")

total_processed_images = 0
for folder_name in processed_folders:
    folder_path = os.path.join(output_folder, folder_name)
    images = [f for f in os.listdir(folder_path) if f.endswith('.jpg')]
    total_processed_images += len(images)
    print(f"  {folder_name}: {len(images)} images")

print(f"\nTotal processed images: {total_processed_images}")
# Out:
# Verification of processed dataset:
# ============================================================
# Total folders in dataset_processed: 66
#   21-45902-3: 20 images
#   22-46138-1: 20 images
#   22-46139-1: 20 images
#   22-46141-1: 20 images
#   22-46275-1: 20 images
#   22-46293-1: 20 images
#   22-46342-1: 20 images
#   22-46473-1: 20 images
#   22-46536-1: 20 images
#   22-46590-1: 20 images
#   22-46666-1: 20 images
#   22-46679-1: 20 images
#   22-46887-1: 20 images
#   22-46945-1: 20 images
#   22-46983-1: 20 images
#   22-47180-1: 20 images
#   22-47294-1: 20 images
#   22-47402-2: 20 images
#   22-47884-2: 20 images
#   22-47892-2: 20 images
#   22-47894-2: 20 images
#   22-47898-2: 20 images
#   22-47925-2: 20 images
#   22-47968-2: 20 images
#   22-48055-2: 20 images
#   22-48064-2: 20 images
#   22-48091-2: 20 images
#   22-48133-2: 20 images
#   22-48205-2: 20 images
#   22-48434-3: 20 images
#   22-48541-3: 20 images
#   22-48569-3: 20 images
#   22-48582-3: 20 images
#   22-48833-3: 20 images
#   22-49037-3: 19 images
#   22-49068-3: 20 images
#   22-49167-3: 20 images
#   22-49196-3: 20 images
#   22-49338-3: 20 images
#   22-49355-3: 20 images
#   22-49370-3: 20 images
#   22-49405-3: 20 images
#   22-49411-3: 20 images
#   22-49421-3: 20 images
#   22-49422-3: 20 images
#   22-49451-3: 20 images
#   22-49453-3: 20 images
#   22-49507-3: 20 images
#   22-49575-3: 20 images
#   22-49609-3: 20 images
#   22-49629-3: 20 images
#   22-49643-3: 20 images
#   22-49745-3: 20 images
#   22-49783-3: 20 images
#   22-49791-3: 20 images
#   22-49800-3: 20 images
#   22-49824-3: 20 images
#   22-49843-3: 20 images
#   22-49852-3: 20 images
#   22-49861-3: 20 images
#   22-49862-3: 20 images
#   23-50158-1: 20 images
#   23-50279-1: 20 images
#   23-50346-1: 20 images
#   23-51127-1: 20 images
#   23-53577-3: 20 images
#
# Total processed images: 1319

# %%
# Display sample of processed images
import matplotlib.pyplot as plt

# Check if there are any processed folders
if not processed_folders or len(processed_folders) == 0:
    print("No processed folders found. Please run the processing cell first.")
else:
    # Get first folder and first few images
    sample_folder = processed_folders[0]
    sample_folder_path = os.path.join(output_folder, sample_folder)
    sample_images = [f for f in os.listdir(sample_folder_path) if f.endswith('.jpg')][:4]

    if len(sample_images) == 0:
        print(f"No JPG images found in {sample_folder}")
    else:
        fig, axes = plt.subplots(1, min(4, len(sample_images)), figsize=(15, 5))
        if len(sample_images) == 1:
            axes = [axes]

        for idx, img_name in enumerate(sample_images):
            img_path = os.path.join(sample_folder_path, img_name)
            img = Image.open(img_path)
            axes[idx].imshow(img)
            axes[idx].set_title(f"{img_name}\n{img.size}")
            axes[idx].axis('off')

        plt.suptitle(f"Sample Images from {sample_folder}")
        plt.tight_layout()
        plt.show()
